# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests 
from config import weather_api_key 
from datetime import datetime

# %%
# Create a set of 2,000 random latitudes and longitudes 

lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Create a list of coordinates 

coordinates = list(lat_lngs)

# %%
# Import citipy 

from citipy import citipy

# %%
# Use citpy to find nearest city & create a list 

cities = []

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 732

# %%
# Create URL for Weather API call 

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=838e89412d914b64e1c9eb950d10f13a

# %%
# Create empty list for data 

city_data = []


print(f"Beginning of Data Retrieval")
print(f"----------------------------")


# Loop through all the cities in the list w/ enumerate.
for i, city in enumerate(cities):
    set_count = len(cities)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {i} of Set {set_count} | {city}")

    
    # Run an API request 
    try:
       
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #city_desc = city_weather["weather"]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        
        # Adding data to city data list 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning of Data Retrieval
# ----------------------------
# Processing Record 0 of Set 732 | port elizabeth
# Processing Record 1 of Set 732 | busselton
# Processing Record 2 of Set 732 | murmashi
# Processing Record 3 of Set 732 | teya
# Processing Record 4 of Set 732 | beitbridge
# Processing Record 5 of Set 732 | ouahigouya
# Processing Record 6 of Set 732 | atuona
# Processing Record 7 of Set 732 | ushuaia
# Processing Record 8 of Set 732 | korla
# Processing Record 9 of Set 732 | mataura
# Processing Record 10 of Set 732 | cape town
# Processing Record 11 of Set 732 | tiksi
# Processing Record 12 of Set 732 | severo-kurilsk
# Processing Record 13 of Set 732 | cidreira
# Processing Record 14 of Set 732 | bredasdorp
# Processing Record 15 of Set 732 | tucupita
# Processing Record 16 of Set 732 | binabalian
# Processing Record 17 of Set 732 | tommot
# Processing Record 18 of Set 732 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 732 | new norfolk
# Processing Record 20 of Set 732 | odweyne
# Processing Record 21 of Set 732 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 732 | alofi
# Processing Record 23 of Set 732 | tura
# Processing Record 24 of Set 732 | la ronge
# Processing Record 25 of Set 732 | biltine
# Processing Record 26 of Set 732 | yulara
# Processing Record 27 of Set 732 | tingo maria
# Processing Record 28 of Set 732 | provideniya
# Processing Record 29 of Set 732 | asuncion
# Processing Record 30 of Set 732 | kodiak
# Processing Record 31 of Set 732 | avarua
# Processing Record 32 of Set 732 | cabo san lucas
# Processing Record 33 of Set 732 | lagoa
# Processing Record 34 of Set 732 | qaanaaq
# Processing Record 35 of Set 732 | biharamulo
# Processing Record 36 of Set 732 | ternate
# Processing Record 37 of Set 732 | albany
# Processing Record 38 of Set 732 | port alfred
# Processing Record 39 of Set 732 | bluff
# Processing Record 40 of Set 732 | valparaiso
# Processing Record 41 of Set 732 | callaguip
# Processing Record 42 of Set 732 | hilo
# Processing Record 43 of Set 732 | hermanus
# Processing Record 44 of Set 732 | touros
# Processing Record 45 of Set 732 | puerto ayora
# Processing Record 46 of Set 732 | madang
# Processing Record 47 of Set 732 | dikson
# Processing Record 48 of Set 732 | tessalit
# Processing Record 49 of Set 732 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 732 | east london
# Processing Record 51 of Set 732 | lebu
# Processing Record 52 of Set 732 | angoram
# Processing Record 53 of Set 732 | tunduru
# City not found. Skipping...
# Processing Record 54 of Set 732 | nokaneng
# Processing Record 55 of Set 732 | mareeba
# Processing Record 56 of Set 732 | jurm
# Processing Record 57 of Set 732 | grand river south east
# City not found. Skipping...
# Processing Record 58 of Set 732 | coihaique
# Processing Record 59 of Set 732 | sao filipe
# Processing Record 60 of Set 732 | faanui
# Processing Record 61 of Set 732 | wamba
# Processing Record 62 of Set 732 | sterlibashevo
# Processing Record 63 of Set 732 | tuktoyaktuk
# Processing Record 64 of Set 732 | ahipara
# Processing Record 65 of Set 732 | lolua
# City not found. Skipping...
# Processing Record 66 of Set 732 | rikitea
# Processing Record 67 of Set 732 | ponta do sol
# Processing Record 68 of Set 732 | les cayes
# Processing Record 69 of Set 732 | bjornevatn
# Processing Record 70 of Set 732 | bathsheba
# Processing Record 71 of Set 732 | kruisfontein
# Processing Record 72 of Set 732 | vieux-habitants
# Processing Record 73 of Set 732 | talnakh
# Processing Record 74 of Set 732 | leh
# Processing Record 75 of Set 732 | coquimbo
# Processing Record 76 of Set 732 | mys shmidta
# City not found. Skipping...
# Processing Record 77 of Set 732 | karratha
# Processing Record 78 of Set 732 | taoudenni
# Processing Record 79 of Set 732 | verkhnyaya inta
# Processing Record 80 of Set 732 | punta arenas
# Processing Record 81 of Set 732 | longyearbyen
# Processing Record 82 of Set 732 | fairbanks
# Processing Record 83 of Set 732 | penzance
# Processing Record 84 of Set 732 | taolanaro
# City not found. Skipping...
# Processing Record 85 of Set 732 | meiktila
# Processing Record 86 of Set 732 | rawson
# Processing Record 87 of Set 732 | havoysund
# Processing Record 88 of Set 732 | nizhneyansk
# City not found. Skipping...
# Processing Record 89 of Set 732 | hihifo
# City not found. Skipping...
# Processing Record 90 of Set 732 | makakilo city
# Processing Record 91 of Set 732 | te anau
# Processing Record 92 of Set 732 | nikolskoye
# Processing Record 93 of Set 732 | pilar
# Processing Record 94 of Set 732 | dunedin
# Processing Record 95 of Set 732 | lufilufi
# Processing Record 96 of Set 732 | najran
# Processing Record 97 of Set 732 | barentsburg
# City not found. Skipping...
# Processing Record 98 of Set 732 | bur gabo
# City not found. Skipping...
# Processing Record 99 of Set 732 | vaini
# Processing Record 100 of Set 732 | rawannawi
# City not found. Skipping...
# Processing Record 101 of Set 732 | portel
# Processing Record 102 of Set 732 | gizo
# Processing Record 103 of Set 732 | kamenskoye
# City not found. Skipping...
# Processing Record 104 of Set 732 | cumaribo
# City not found. Skipping...
# Processing Record 105 of Set 732 | nianzishan
# Processing Record 106 of Set 732 | cabedelo
# Processing Record 107 of Set 732 | tautira
# Processing Record 108 of Set 732 | norman wells
# Processing Record 109 of Set 732 | san patricio
# Processing Record 110 of Set 732 | charters towers
# Processing Record 111 of Set 732 | jagdalpur
# Processing Record 112 of Set 732 | warqla
# City not found. Skipping...
# Processing Record 113 of Set 732 | illela
# Processing Record 114 of Set 732 | kavieng
# Processing Record 115 of Set 732 | libenge
# Processing Record 116 of Set 732 | lakatoro
# Processing Record 117 of Set 732 | pemangkat
# Processing Record 118 of Set 732 | caceres
# Processing Record 119 of Set 732 | geraldton
# Processing Record 120 of Set 732 | nakhon si thammarat
# Processing Record 121 of Set 732 | mazamitla
# Processing Record 122 of Set 732 | louga
# Processing Record 123 of Set 732 | barrow
# Processing Record 124 of Set 732 | avera
# Processing Record 125 of Set 732 | sitka
# Processing Record 126 of Set 732 | carnarvon
# Processing Record 127 of Set 732 | tasiilaq
# Processing Record 128 of Set 732 | khatanga
# Processing Record 129 of Set 732 | ngorongoro
# Processing Record 130 of Set 732 | san juan
# Processing Record 131 of Set 732 | batticaloa
# Processing Record 132 of Set 732 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 133 of Set 732 | attawapiskat
# City not found. Skipping...
# Processing Record 134 of Set 732 | vao
# Processing Record 135 of Set 732 | aklavik
# Processing Record 136 of Set 732 | chapais
# Processing Record 137 of Set 732 | aguimes
# Processing Record 138 of Set 732 | brora
# Processing Record 139 of Set 732 | jhalrapatan
# Processing Record 140 of Set 732 | sioux lookout
# Processing Record 141 of Set 732 | ouadda
# Processing Record 142 of Set 732 | saint-philippe
# Processing Record 143 of Set 732 | salalah
# Processing Record 144 of Set 732 | port lincoln
# Processing Record 145 of Set 732 | satitoa
# City not found. Skipping...
# Processing Record 146 of Set 732 | coahuayana
# Processing Record 147 of Set 732 | hofn
# Processing Record 148 of Set 732 | basoko
# Processing Record 149 of Set 732 | kapoeta
# Processing Record 150 of Set 732 | sherlovaya gora
# Processing Record 151 of Set 732 | los llanos de aridane
# Processing Record 152 of Set 732 | komsomolskiy
# Processing Record 153 of Set 732 | sycamore
# Processing Record 154 of Set 732 | horsham
# Processing Record 155 of Set 732 | palabuhanratu
# City not found. Skipping...
# Processing Record 156 of Set 732 | pendencias
# Processing Record 157 of Set 732 | thompson
# Processing Record 158 of Set 732 | acarau
# Processing Record 159 of Set 732 | saint george
# Processing Record 160 of Set 732 | san rafael del sur
# Processing Record 161 of Set 732 | klaksvik
# Processing Record 162 of Set 732 | kavaratti
# Processing Record 163 of Set 732 | luis correia
# Processing Record 164 of Set 732 | port hardy
# Processing Record 165 of Set 732 | hobart
# Processing Record 166 of Set 732 | verkhoyansk
# Processing Record 167 of Set 732 | mrakovo
# Processing Record 168 of Set 732 | saryshagan
# City not found. Skipping...
# Processing Record 169 of Set 732 | lasa
# Processing Record 170 of Set 732 | jamestown
# Processing Record 171 of Set 732 | vestmannaeyjar
# Processing Record 172 of Set 732 | ekibastuz
# Processing Record 173 of Set 732 | castro
# Processing Record 174 of Set 732 | aragarcas
# Processing Record 175 of Set 732 | ilulissat
# Processing Record 176 of Set 732 | portoferraio
# Processing Record 177 of Set 732 | hovd
# Processing Record 178 of Set 732 | camana
# Processing Record 179 of Set 732 | dawei
# Processing Record 180 of Set 732 | lompoc
# Processing Record 181 of Set 732 | georgetown
# Processing Record 182 of Set 732 | yellowknife
# Processing Record 183 of Set 732 | iwanai
# Processing Record 184 of Set 732 | blackfoot
# Processing Record 185 of Set 732 | linxia
# Processing Record 186 of Set 732 | colac
# Processing Record 187 of Set 732 | brownfield
# Processing Record 188 of Set 732 | nagai
# Processing Record 189 of Set 732 | tumannyy
# City not found. Skipping...
# Processing Record 190 of Set 732 | belushya guba
# City not found. Skipping...
# Processing Record 191 of Set 732 | clyde river
# Processing Record 192 of Set 732 | grindavik
# Processing Record 193 of Set 732 | butaritari
# Processing Record 194 of Set 732 | bengkulu
# Processing Record 195 of Set 732 | fort saint john
# City not found. Skipping...
# Processing Record 196 of Set 732 | tondano
# Processing Record 197 of Set 732 | christchurch
# Processing Record 198 of Set 732 | mahadday weyne
# City not found. Skipping...
# Processing Record 199 of Set 732 | alugan
# Processing Record 200 of Set 732 | san martin
# Processing Record 201 of Set 732 | hamilton
# Processing Record 202 of Set 732 | pevek
# Processing Record 203 of Set 732 | palmer
# Processing Record 204 of Set 732 | imeni poliny osipenko
# Processing Record 205 of Set 732 | wajima
# Processing Record 206 of Set 732 | ancud
# Processing Record 207 of Set 732 | mount gambier
# Processing Record 208 of Set 732 | saleaula
# City not found. Skipping...
# Processing Record 209 of Set 732 | bowen
# Processing Record 210 of Set 732 | joao pinheiro
# Processing Record 211 of Set 732 | ruatoria
# City not found. Skipping...
# Processing Record 212 of Set 732 | cherskiy
# Processing Record 213 of Set 732 | mehamn
# Processing Record 214 of Set 732 | lavrentiya
# Processing Record 215 of Set 732 | necochea
# Processing Record 216 of Set 732 | fare
# Processing Record 217 of Set 732 | shetpe
# Processing Record 218 of Set 732 | kapaa
# Processing Record 219 of Set 732 | meulaboh
# Processing Record 220 of Set 732 | do gonbadan
# Processing Record 221 of Set 732 | bishop auckland
# Processing Record 222 of Set 732 | hasaki
# Processing Record 223 of Set 732 | honningsvag
# Processing Record 224 of Set 732 | marcona
# City not found. Skipping...
# Processing Record 225 of Set 732 | henzada
# City not found. Skipping...
# Processing Record 226 of Set 732 | taungdwingyi
# Processing Record 227 of Set 732 | ostersund
# Processing Record 228 of Set 732 | kindu
# Processing Record 229 of Set 732 | gornopravdinsk
# Processing Record 230 of Set 732 | waipawa
# Processing Record 231 of Set 732 | burnie
# Processing Record 232 of Set 732 | bonthe
# Processing Record 233 of Set 732 | hukuntsi
# Processing Record 234 of Set 732 | manavgat
# Processing Record 235 of Set 732 | bethel
# Processing Record 236 of Set 732 | saldanha
# Processing Record 237 of Set 732 | kango
# Processing Record 238 of Set 732 | chanika
# Processing Record 239 of Set 732 | saskylakh
# Processing Record 240 of Set 732 | mosta
# Processing Record 241 of Set 732 | gat
# Processing Record 242 of Set 732 | kahului
# Processing Record 243 of Set 732 | okitipupa
# Processing Record 244 of Set 732 | chokurdakh
# Processing Record 245 of Set 732 | belmonte
# Processing Record 246 of Set 732 | vanimo
# Processing Record 247 of Set 732 | qixingtai
# Processing Record 248 of Set 732 | port keats
# Processing Record 249 of Set 732 | cayenne
# Processing Record 250 of Set 732 | mandera
# Processing Record 251 of Set 732 | fort nelson
# Processing Record 252 of Set 732 | kholodnyy
# Processing Record 253 of Set 732 | karaul
# City not found. Skipping...
# Processing Record 254 of Set 732 | alice springs
# Processing Record 255 of Set 732 | la paz
# Processing Record 256 of Set 732 | kaitangata
# Processing Record 257 of Set 732 | qasigiannguit
# Processing Record 258 of Set 732 | zhetybay
# City not found. Skipping...
# Processing Record 259 of Set 732 | victoria
# Processing Record 260 of Set 732 | inhambane
# Processing Record 261 of Set 732 | beringovskiy
# Processing Record 262 of Set 732 | marau
# Processing Record 263 of Set 732 | mufumbwe
# Processing Record 264 of Set 732 | kjollefjord
# Processing Record 265 of Set 732 | fortuna
# Processing Record 266 of Set 732 | sarakhs
# Processing Record 267 of Set 732 | luderitz
# Processing Record 268 of Set 732 | kalabo
# Processing Record 269 of Set 732 | camacha
# Processing Record 270 of Set 732 | red bluff
# Processing Record 271 of Set 732 | laukaa
# Processing Record 272 of Set 732 | chuy
# Processing Record 273 of Set 732 | the pas
# Processing Record 274 of Set 732 | bull savanna
# Processing Record 275 of Set 732 | khor
# Processing Record 276 of Set 732 | pochutla
# Processing Record 277 of Set 732 | bollnas
# Processing Record 278 of Set 732 | mezen
# Processing Record 279 of Set 732 | aripuana
# Processing Record 280 of Set 732 | san vicente
# Processing Record 281 of Set 732 | mwense
# Processing Record 282 of Set 732 | shingu
# Processing Record 283 of Set 732 | vaniyambadi
# Processing Record 284 of Set 732 | vardo
# Processing Record 285 of Set 732 | awjilah
# Processing Record 286 of Set 732 | hithadhoo
# Processing Record 287 of Set 732 | saint-joseph
# Processing Record 288 of Set 732 | iberia
# Processing Record 289 of Set 732 | kremsmunster
# Processing Record 290 of Set 732 | ngunguru
# Processing Record 291 of Set 732 | mattru
# Processing Record 292 of Set 732 | bambous virieux
# Processing Record 293 of Set 732 | samana
# Processing Record 294 of Set 732 | guerrero negro
# Processing Record 295 of Set 732 | goba
# Processing Record 296 of Set 732 | nago
# Processing Record 297 of Set 732 | ferkessedougou
# Processing Record 298 of Set 732 | margate
# Processing Record 299 of Set 732 | novoagansk
# Processing Record 300 of Set 732 | san cristobal
# Processing Record 301 of Set 732 | buarcos
# Processing Record 302 of Set 732 | peniche
# Processing Record 303 of Set 732 | prince george
# Processing Record 304 of Set 732 | padang
# Processing Record 305 of Set 732 | cuamba
# Processing Record 306 of Set 732 | beidao
# Processing Record 307 of Set 732 | atambua
# Processing Record 308 of Set 732 | jacareacanga
# Processing Record 309 of Set 732 | sawakin
# Processing Record 310 of Set 732 | ha giang
# Processing Record 311 of Set 732 | katsuura
# Processing Record 312 of Set 732 | galgani
# City not found. Skipping...
# Processing Record 313 of Set 732 | mayumba
# Processing Record 314 of Set 732 | torbay
# Processing Record 315 of Set 732 | richards bay
# Processing Record 316 of Set 732 | saint-georges
# Processing Record 317 of Set 732 | bundaberg
# Processing Record 318 of Set 732 | henties bay
# Processing Record 319 of Set 732 | airai
# Processing Record 320 of Set 732 | haines junction
# Processing Record 321 of Set 732 | vila velha
# Processing Record 322 of Set 732 | narsaq
# Processing Record 323 of Set 732 | sosnovo-ozerskoye
# Processing Record 324 of Set 732 | esperance
# Processing Record 325 of Set 732 | mahebourg
# Processing Record 326 of Set 732 | cartagena
# Processing Record 327 of Set 732 | codrington
# Processing Record 328 of Set 732 | cooma
# Processing Record 329 of Set 732 | sao joao da barra
# Processing Record 330 of Set 732 | tilichiki
# Processing Record 331 of Set 732 | anadyr
# Processing Record 332 of Set 732 | nantucket
# Processing Record 333 of Set 732 | conde
# Processing Record 334 of Set 732 | banjarmasin
# Processing Record 335 of Set 732 | yumen
# Processing Record 336 of Set 732 | upernavik
# Processing Record 337 of Set 732 | stornoway
# Processing Record 338 of Set 732 | high level
# Processing Record 339 of Set 732 | elmira
# Processing Record 340 of Set 732 | zyryanka
# Processing Record 341 of Set 732 | araouane
# Processing Record 342 of Set 732 | mogadishu
# Processing Record 343 of Set 732 | uaua
# Processing Record 344 of Set 732 | ponta delgada
# Processing Record 345 of Set 732 | arraial do cabo
# Processing Record 346 of Set 732 | fuyang
# Processing Record 347 of Set 732 | fuerte olimpo
# Processing Record 348 of Set 732 | leningradskiy
# Processing Record 349 of Set 732 | riviere-au-renard
# Processing Record 350 of Set 732 | iquitos
# Processing Record 351 of Set 732 | batemans bay
# Processing Record 352 of Set 732 | sur
# Processing Record 353 of Set 732 | saint-augustin
# Processing Record 354 of Set 732 | tiznit
# Processing Record 355 of Set 732 | severnoye
# Processing Record 356 of Set 732 | khonuu
# City not found. Skipping...
# Processing Record 357 of Set 732 | samarai
# Processing Record 358 of Set 732 | kyra
# Processing Record 359 of Set 732 | virginia beach
# Processing Record 360 of Set 732 | hami
# Processing Record 361 of Set 732 | araguacu
# Processing Record 362 of Set 732 | alyangula
# Processing Record 363 of Set 732 | bubaque
# Processing Record 364 of Set 732 | adrar
# Processing Record 365 of Set 732 | goderich
# Processing Record 366 of Set 732 | passos
# Processing Record 367 of Set 732 | koygorodok
# Processing Record 368 of Set 732 | dandong
# Processing Record 369 of Set 732 | burica
# City not found. Skipping...
# Processing Record 370 of Set 732 | saint-pierre
# Processing Record 371 of Set 732 | gola gokarannath
# Processing Record 372 of Set 732 | constitucion
# Processing Record 373 of Set 732 | prado
# Processing Record 374 of Set 732 | bensonville
# Processing Record 375 of Set 732 | galle
# Processing Record 376 of Set 732 | kaabong
# Processing Record 377 of Set 732 | walla walla
# Processing Record 378 of Set 732 | sungairaya
# Processing Record 379 of Set 732 | klaeng
# Processing Record 380 of Set 732 | celestun
# Processing Record 381 of Set 732 | rosario
# Processing Record 382 of Set 732 | senanga
# Processing Record 383 of Set 732 | tazovskiy
# Processing Record 384 of Set 732 | guilin
# Processing Record 385 of Set 732 | jizan
# Processing Record 386 of Set 732 | great falls
# Processing Record 387 of Set 732 | dzhusaly
# City not found. Skipping...
# Processing Record 388 of Set 732 | broken hill
# Processing Record 389 of Set 732 | kichmengskiy gorodok
# Processing Record 390 of Set 732 | bonavista
# Processing Record 391 of Set 732 | barawe
# City not found. Skipping...
# Processing Record 392 of Set 732 | priargunsk
# Processing Record 393 of Set 732 | karamea
# City not found. Skipping...
# Processing Record 394 of Set 732 | torres
# Processing Record 395 of Set 732 | qui nhon
# Processing Record 396 of Set 732 | bayangol
# Processing Record 397 of Set 732 | savinskiy
# Processing Record 398 of Set 732 | lincoln
# Processing Record 399 of Set 732 | rorvik
# Processing Record 400 of Set 732 | victoria point
# Processing Record 401 of Set 732 | kamaishi
# Processing Record 402 of Set 732 | yanan
# City not found. Skipping...
# Processing Record 403 of Set 732 | mar del plata
# Processing Record 404 of Set 732 | vaitupu
# City not found. Skipping...
# Processing Record 405 of Set 732 | kungurtug
# Processing Record 406 of Set 732 | axim
# Processing Record 407 of Set 732 | sao felix do xingu
# Processing Record 408 of Set 732 | port hawkesbury
# Processing Record 409 of Set 732 | laguna
# Processing Record 410 of Set 732 | narrabri
# Processing Record 411 of Set 732 | grand baie
# Processing Record 412 of Set 732 | katherine
# Processing Record 413 of Set 732 | alotau
# City not found. Skipping...
# Processing Record 414 of Set 732 | antofagasta
# Processing Record 415 of Set 732 | roma
# Processing Record 416 of Set 732 | gamba
# Processing Record 417 of Set 732 | el retorno
# Processing Record 418 of Set 732 | molteno
# Processing Record 419 of Set 732 | tuatapere
# Processing Record 420 of Set 732 | kursavka
# Processing Record 421 of Set 732 | kayerkan
# Processing Record 422 of Set 732 | comodoro rivadavia
# Processing Record 423 of Set 732 | aykhal
# Processing Record 424 of Set 732 | santo tomas
# Processing Record 425 of Set 732 | eselnita
# Processing Record 426 of Set 732 | tigil
# Processing Record 427 of Set 732 | general roca
# Processing Record 428 of Set 732 | san quintin
# Processing Record 429 of Set 732 | kieta
# Processing Record 430 of Set 732 | salto
# Processing Record 431 of Set 732 | carballo
# Processing Record 432 of Set 732 | huilong
# Processing Record 433 of Set 732 | takaka
# Processing Record 434 of Set 732 | misratah
# Processing Record 435 of Set 732 | port hedland
# Processing Record 436 of Set 732 | wisla
# Processing Record 437 of Set 732 | datong
# Processing Record 438 of Set 732 | ngukurr
# City not found. Skipping...
# Processing Record 439 of Set 732 | kalmunai
# Processing Record 440 of Set 732 | envira
# Processing Record 441 of Set 732 | umzimvubu
# City not found. Skipping...
# Processing Record 442 of Set 732 | usinsk
# Processing Record 443 of Set 732 | pitimbu
# Processing Record 444 of Set 732 | conakry
# Processing Record 445 of Set 732 | kiunga
# Processing Record 446 of Set 732 | flinders
# Processing Record 447 of Set 732 | maraa
# Processing Record 448 of Set 732 | kyshtovka
# Processing Record 449 of Set 732 | tsubata
# Processing Record 450 of Set 732 | panzhihua
# Processing Record 451 of Set 732 | priiskovyy
# Processing Record 452 of Set 732 | dongying
# Processing Record 453 of Set 732 | baherden
# Processing Record 454 of Set 732 | kropotkin
# Processing Record 455 of Set 732 | saint-leu
# Processing Record 456 of Set 732 | scottsburgh
# City not found. Skipping...
# Processing Record 457 of Set 732 | mangan
# Processing Record 458 of Set 732 | longlac
# City not found. Skipping...
# Processing Record 459 of Set 732 | paamiut
# Processing Record 460 of Set 732 | adamovka
# Processing Record 461 of Set 732 | la palma
# Processing Record 462 of Set 732 | port-gentil
# Processing Record 463 of Set 732 | gorele
# Processing Record 464 of Set 732 | umm lajj
# Processing Record 465 of Set 732 | turtkul
# City not found. Skipping...
# Processing Record 466 of Set 732 | moron
# Processing Record 467 of Set 732 | tocopilla
# Processing Record 468 of Set 732 | cangzhou
# Processing Record 469 of Set 732 | hare bay
# Processing Record 470 of Set 732 | mecca
# Processing Record 471 of Set 732 | sayyan
# Processing Record 472 of Set 732 | amurrio
# Processing Record 473 of Set 732 | sena madureira
# Processing Record 474 of Set 732 | luebo
# Processing Record 475 of Set 732 | nabire
# Processing Record 476 of Set 732 | elizabeth city
# Processing Record 477 of Set 732 | acajutla
# Processing Record 478 of Set 732 | naze
# Processing Record 479 of Set 732 | akot
# Processing Record 480 of Set 732 | mandalgovi
# Processing Record 481 of Set 732 | khonsa
# Processing Record 482 of Set 732 | bardiyah
# Processing Record 483 of Set 732 | neiafu
# Processing Record 484 of Set 732 | svetlogorsk
# Processing Record 485 of Set 732 | port macquarie
# Processing Record 486 of Set 732 | kautokeino
# Processing Record 487 of Set 732 | baruun-urt
# Processing Record 488 of Set 732 | utiroa
# City not found. Skipping...
# Processing Record 489 of Set 732 | pozoblanco
# Processing Record 490 of Set 732 | atar
# Processing Record 491 of Set 732 | waitati
# Processing Record 492 of Set 732 | arrecife
# Processing Record 493 of Set 732 | cockburn town
# Processing Record 494 of Set 732 | liyang
# Processing Record 495 of Set 732 | lodja
# Processing Record 496 of Set 732 | dmitriyevka
# Processing Record 497 of Set 732 | quatre cocos
# Processing Record 498 of Set 732 | nioro
# Processing Record 499 of Set 732 | abnub
# Processing Record 500 of Set 732 | maniitsoq
# Processing Record 501 of Set 732 | kununurra
# Processing Record 502 of Set 732 | dawlatabad
# Processing Record 503 of Set 732 | yabrud
# Processing Record 504 of Set 732 | tevriz
# Processing Record 505 of Set 732 | bilibino
# Processing Record 506 of Set 732 | pampa
# Processing Record 507 of Set 732 | san felipe
# Processing Record 508 of Set 732 | bokspits
# City not found. Skipping...
# Processing Record 509 of Set 732 | jishou
# Processing Record 510 of Set 732 | taltal
# Processing Record 511 of Set 732 | bocaranga
# City not found. Skipping...
# Processing Record 512 of Set 732 | garden city
# Processing Record 513 of Set 732 | egvekinot
# Processing Record 514 of Set 732 | baykit
# Processing Record 515 of Set 732 | toowoomba
# Processing Record 516 of Set 732 | wulanhaote
# City not found. Skipping...
# Processing Record 517 of Set 732 | winnemucca
# Processing Record 518 of Set 732 | yerbogachen
# Processing Record 519 of Set 732 | joigny
# Processing Record 520 of Set 732 | port blair
# Processing Record 521 of Set 732 | bargal
# City not found. Skipping...
# Processing Record 522 of Set 732 | marsaxlokk
# Processing Record 523 of Set 732 | mount isa
# Processing Record 524 of Set 732 | barreirinhas
# Processing Record 525 of Set 732 | kostino
# Processing Record 526 of Set 732 | katangli
# Processing Record 527 of Set 732 | buraydah
# Processing Record 528 of Set 732 | praia
# Processing Record 529 of Set 732 | chabahar
# Processing Record 530 of Set 732 | juneau
# Processing Record 531 of Set 732 | rocha
# Processing Record 532 of Set 732 | husavik
# Processing Record 533 of Set 732 | straumen
# Processing Record 534 of Set 732 | ostrovnoy
# Processing Record 535 of Set 732 | safaga
# Processing Record 536 of Set 732 | nouadhibou
# Processing Record 537 of Set 732 | blagoveshchensk
# Processing Record 538 of Set 732 | sao jose da coroa grande
# Processing Record 539 of Set 732 | shahrud
# Processing Record 540 of Set 732 | nguiu
# City not found. Skipping...
# Processing Record 541 of Set 732 | port augusta
# Processing Record 542 of Set 732 | skeldon
# Processing Record 543 of Set 732 | felidhoo
# City not found. Skipping...
# Processing Record 544 of Set 732 | batagay-alyta
# Processing Record 545 of Set 732 | daitari
# Processing Record 546 of Set 732 | la macarena
# Processing Record 547 of Set 732 | ribeira grande
# Processing Record 548 of Set 732 | gomel
# Processing Record 549 of Set 732 | humberto de campos
# Processing Record 550 of Set 732 | nanortalik
# Processing Record 551 of Set 732 | hualmay
# Processing Record 552 of Set 732 | jalgaon
# Processing Record 553 of Set 732 | ottawa
# Processing Record 554 of Set 732 | bac lieu
# Processing Record 555 of Set 732 | fort-shevchenko
# Processing Record 556 of Set 732 | nelson bay
# Processing Record 557 of Set 732 | kitui
# Processing Record 558 of Set 732 | hunterville
# Processing Record 559 of Set 732 | aborlan
# Processing Record 560 of Set 732 | remedios
# Processing Record 561 of Set 732 | tanout
# Processing Record 562 of Set 732 | serebryansk
# Processing Record 563 of Set 732 | talara
# Processing Record 564 of Set 732 | kazachinskoye
# Processing Record 565 of Set 732 | lorengau
# Processing Record 566 of Set 732 | challans
# Processing Record 567 of Set 732 | pangody
# Processing Record 568 of Set 732 | perth
# Processing Record 569 of Set 732 | toliary
# City not found. Skipping...
# Processing Record 570 of Set 732 | futtsu
# Processing Record 571 of Set 732 | thinadhoo
# Processing Record 572 of Set 732 | myaundzha
# Processing Record 573 of Set 732 | massakory
# Processing Record 574 of Set 732 | mercedes
# Processing Record 575 of Set 732 | foumban
# Processing Record 576 of Set 732 | trabzon
# Processing Record 577 of Set 732 | bitkine
# Processing Record 578 of Set 732 | kottayam
# Processing Record 579 of Set 732 | nyrob
# Processing Record 580 of Set 732 | viking
# Processing Record 581 of Set 732 | gasa
# Processing Record 582 of Set 732 | ziyang
# Processing Record 583 of Set 732 | celadna
# Processing Record 584 of Set 732 | asau
# Processing Record 585 of Set 732 | uusikaupunki
# Processing Record 586 of Set 732 | puerto madryn
# Processing Record 587 of Set 732 | whyalla
# Processing Record 588 of Set 732 | nunoa
# Processing Record 589 of Set 732 | ust-tsilma
# Processing Record 590 of Set 732 | kracheh
# City not found. Skipping...
# Processing Record 591 of Set 732 | dicabisagan
# Processing Record 592 of Set 732 | iqaluit
# Processing Record 593 of Set 732 | armacao dos buzios
# City not found. Skipping...
# Processing Record 594 of Set 732 | trinidad
# Processing Record 595 of Set 732 | witney
# Processing Record 596 of Set 732 | mizan teferi
# Processing Record 597 of Set 732 | polunochnoye
# Processing Record 598 of Set 732 | stephenville
# Processing Record 599 of Set 732 | labrea
# Processing Record 600 of Set 732 | amahai
# Processing Record 601 of Set 732 | gillette
# Processing Record 602 of Set 732 | magdagachi
# Processing Record 603 of Set 732 | maumere
# Processing Record 604 of Set 732 | camocim
# Processing Record 605 of Set 732 | iracoubo
# Processing Record 606 of Set 732 | oranjemund
# Processing Record 607 of Set 732 | mogochin
# City not found. Skipping...
# Processing Record 608 of Set 732 | buala
# Processing Record 609 of Set 732 | yanchukan
# City not found. Skipping...
# Processing Record 610 of Set 732 | valdez
# Processing Record 611 of Set 732 | faya
# Processing Record 612 of Set 732 | wucheng
# Processing Record 613 of Set 732 | tsihombe
# City not found. Skipping...
# Processing Record 614 of Set 732 | golyshmanovo
# Processing Record 615 of Set 732 | arman
# Processing Record 616 of Set 732 | kathmandu
# Processing Record 617 of Set 732 | barcelos
# Processing Record 618 of Set 732 | muisne
# Processing Record 619 of Set 732 | vaitape
# Processing Record 620 of Set 732 | loganville
# Processing Record 621 of Set 732 | puerto del rosario
# Processing Record 622 of Set 732 | estrela
# Processing Record 623 of Set 732 | imbituba
# Processing Record 624 of Set 732 | lazaro cardenas
# Processing Record 625 of Set 732 | maua
# Processing Record 626 of Set 732 | hailey
# Processing Record 627 of Set 732 | kabanjahe
# Processing Record 628 of Set 732 | san-pedro
# Processing Record 629 of Set 732 | jutai
# Processing Record 630 of Set 732 | angoche
# Processing Record 631 of Set 732 | jawor
# Processing Record 632 of Set 732 | kaitong
# Processing Record 633 of Set 732 | sambava
# Processing Record 634 of Set 732 | campbellton
# Processing Record 635 of Set 732 | zyryanovsk
# Processing Record 636 of Set 732 | birin
# Processing Record 637 of Set 732 | ranfurly
# Processing Record 638 of Set 732 | santa luzia
# Processing Record 639 of Set 732 | sechura
# Processing Record 640 of Set 732 | ariquemes
# Processing Record 641 of Set 732 | konya
# Processing Record 642 of Set 732 | katsina
# Processing Record 643 of Set 732 | montepuez
# Processing Record 644 of Set 732 | sabzevar
# Processing Record 645 of Set 732 | crotone
# Processing Record 646 of Set 732 | alto araguaia
# Processing Record 647 of Set 732 | tasbuget
# City not found. Skipping...
# Processing Record 648 of Set 732 | opobo
# City not found. Skipping...
# Processing Record 649 of Set 732 | vila do maio
# Processing Record 650 of Set 732 | matara
# Processing Record 651 of Set 732 | dong hoi
# Processing Record 652 of Set 732 | dwarka
# Processing Record 653 of Set 732 | natitingou
# Processing Record 654 of Set 732 | kantilo
# Processing Record 655 of Set 732 | miri
# Processing Record 656 of Set 732 | remerschen
# Processing Record 657 of Set 732 | sandominic
# Processing Record 658 of Set 732 | tukrah
# Processing Record 659 of Set 732 | tarakan
# Processing Record 660 of Set 732 | aswan
# Processing Record 661 of Set 732 | sorland
# Processing Record 662 of Set 732 | kemijarvi
# Processing Record 663 of Set 732 | kattivakkam
# Processing Record 664 of Set 732 | alamogordo
# Processing Record 665 of Set 732 | yekepa
# Processing Record 666 of Set 732 | stolin
# Processing Record 667 of Set 732 | maradi
# Processing Record 668 of Set 732 | mount pleasant
# Processing Record 669 of Set 732 | makung
# City not found. Skipping...
# Processing Record 670 of Set 732 | lazarev
# Processing Record 671 of Set 732 | santa cruz
# Processing Record 672 of Set 732 | hauterive
# Processing Record 673 of Set 732 | rio verde de mato grosso
# Processing Record 674 of Set 732 | sinnamary
# Processing Record 675 of Set 732 | broome
# Processing Record 676 of Set 732 | urdzhar
# City not found. Skipping...
# Processing Record 677 of Set 732 | nagua
# Processing Record 678 of Set 732 | falam
# Processing Record 679 of Set 732 | tornio
# Processing Record 680 of Set 732 | solginskiy
# Processing Record 681 of Set 732 | tuscaloosa
# Processing Record 682 of Set 732 | presidencia roque saenz pena
# Processing Record 683 of Set 732 | lodwar
# Processing Record 684 of Set 732 | garachine
# Processing Record 685 of Set 732 | samandag
# Processing Record 686 of Set 732 | louisbourg
# City not found. Skipping...
# Processing Record 687 of Set 732 | itupiranga
# Processing Record 688 of Set 732 | ciudad guayana
# Processing Record 689 of Set 732 | meoqui
# Processing Record 690 of Set 732 | ajnala
# Processing Record 691 of Set 732 | evensk
# Processing Record 692 of Set 732 | vostok
# Processing Record 693 of Set 732 | mhlume
# Processing Record 694 of Set 732 | voloiac
# Processing Record 695 of Set 732 | summerville
# Processing Record 696 of Set 732 | saint-francois
# Processing Record 697 of Set 732 | along
# Processing Record 698 of Set 732 | salinas
# Processing Record 699 of Set 732 | guarapari
# Processing Record 700 of Set 732 | okulovka
# Processing Record 701 of Set 732 | waingapu
# Processing Record 702 of Set 732 | inirida
# Processing Record 703 of Set 732 | shuyskoye
# Processing Record 704 of Set 732 | ardon
# Processing Record 705 of Set 732 | puerto colombia
# Processing Record 706 of Set 732 | whitehorse
# Processing Record 707 of Set 732 | meyungs
# City not found. Skipping...
# Processing Record 708 of Set 732 | prince rupert
# Processing Record 709 of Set 732 | talcahuano
# Processing Record 710 of Set 732 | zhigansk
# Processing Record 711 of Set 732 | halalo
# City not found. Skipping...
# Processing Record 712 of Set 732 | khipro
# Processing Record 713 of Set 732 | altagracia de orituco
# Processing Record 714 of Set 732 | mumbwa
# Processing Record 715 of Set 732 | bilma
# Processing Record 716 of Set 732 | pisco
# Processing Record 717 of Set 732 | wani
# Processing Record 718 of Set 732 | college
# Processing Record 719 of Set 732 | agucadoura
# Processing Record 720 of Set 732 | nhulunbuy
# Processing Record 721 of Set 732 | kendal
# Processing Record 722 of Set 732 | tijuana
# Processing Record 723 of Set 732 | srednekolymsk
# Processing Record 724 of Set 732 | waw
# Processing Record 725 of Set 732 | kudahuvadhoo
# Processing Record 726 of Set 732 | kinablangan
# Processing Record 727 of Set 732 | nacala
# Processing Record 728 of Set 732 | nouakchott
# Processing Record 729 of Set 732 | ende
# Processing Record 730 of Set 732 | deputatskiy
# Processing Record 731 of Set 732 | honiara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
test_url = url + "&q=" + "dingle"
test = requests.get(test_url)
test.json()

# %%
test_data = test.json()
test_data['weather'][0]['description']

# %%
# Create a dataframe 

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180   25.5701     59.00        94          90
# 1       Busselton      AU -33.6500  115.3333     68.00        73          21
# 2        Murmashi      RU  68.8154   32.8115     28.40        54           0
# 3            Teya      RU  60.3778   92.6267     28.45        78          94
# 4      Beitbridge      ZW -22.2167   30.0000     66.40        68           0
#
#    Wind Speed Current Description
# 0        4.61                 fog
# 1        1.99          few clouds
# 2        6.71           clear sky
# 3        7.47     overcast clouds
# 4        0.67           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
